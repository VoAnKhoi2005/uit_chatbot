# %%
from neo4j import GraphDatabase

uri = "neo4j://127.0.0.1:7687"
username = "neo4j"
password = "1234567890"

driver = GraphDatabase.driver(uri, auth=(username, password))
neo4j_session = driver.session(database="ontology")

# %%
def count_graph_elements(tx):
    node_count_query = "MATCH (n) RETURN count(n) AS node_count"
    rel_count_query = "MATCH ()-[r]->() RETURN count(r) AS rel_count"

    node_result = tx.run(node_count_query).single()
    rel_result = tx.run(rel_count_query).single()

    node_count = node_result["node_count"]
    rel_count = rel_result["rel_count"]

    return node_count, rel_count

# %%
with neo4j_session.begin_transaction() as tx:
    node_count, rel_count = count_graph_elements(tx)
    print(f"Total concepts (nodes): {node_count}")
    print(f"Total relations (edges): {rel_count}")
# Out:
# Total concepts (nodes): 4023
# Total relations (edges): 6918

# %%
import os

def export_relation_names_to_txt(session, output_path="relations.txt"):
    """
    Export all unique relation names (r.name) from Neo4j to a text file.
    Each line in the file will contain one relation name.
    """
    with session.begin_transaction() as tx:
        result = tx.run("""
            MATCH ()-[r:RELATION]->()
            WHERE r.name IS NOT NULL
            RETURN DISTINCT r.name AS relation_name
            ORDER BY r.name
        """)
        relation_names = [record["relation_name"] for record in result]

    # Write to file
    directory = os.path.dirname(output_path)
    if directory:
        os.makedirs(directory, exist_ok=True)
    with open(output_path, "w", encoding="utf-8") as f:
        for name in relation_names:
            f.write(name.strip() + "\n")

    print(f"✅ Exported {len(relation_names)} unique relation names to {output_path}")

    return relation_names

# %%
export_relation_names_to_txt(neo4j_session, "relation_names.txt")
# Out:
# ✅ Exported 841 unique relation names to relation_names.txt
# ['A36',
#  'B4',
#  'C115',
#  'C184',
#  'C212',
#  'C225',
#  'C281',
#  'C304',
#  'C310',
#  'D101',
#  'D60',
#  'D83',
#  'D96',
#  'E100',
#  'F140',
#  'F263',
#  'F280',
#  'F66',
#  'G111',
#  'G115',
#  'G117',
#  'G143',
#  'G154',
#  'G190',
#  'G207',
#  'G25',
#  'G289',
#  'G30',
#  'G32',
#  'G4',
#  'G60',
#  'G63',
#  'G72',
#  'H17',
#  'H184',
#  'H245',
#  'H25',
#  'H26',
#  'I103',
#  'I12',
#  'I26',
#  'I3',
#  'I42',
#  'I43',
#  'I7',
#  'I81',
#  'J130',
#  'J136',
#  'J137',
#  'J144',
#  'J153',
#  'J211',
#  'J215',
#  'J217',
#  'J227',
#  'J236',
#  'J33',
#  'J36',
#  'J40',
#  'J47',
#  'J60',
#  'J88',
#  'K144',
#  'K59',
#  'K79',
#  'L174',
#  'L226',
#  'L273',
#  'L37',
#  'M1',
#  'M105',
#  'M223',
#  'M26',
#  'M4',
#  'M50',
#  'M51',
#  'M52',
#  'M53',
#  'M54',
#  'M57',
#  'M64',
#  'M7',
#  'M72',
#  'M8',
#  'M9',
#  'N1',
#  'N10',
#  'N107',
#  'N123',
#  'N126',
#  'N130',
#  'N131',
#  'N134',
#  'N135',
#  'N138',
#  'N139',
#  'N150',
#  'N151',
#  'N154',
#  'N157',
#  'N158',
#  'N160',
#  'N163',
#  'N165',
#  'N167',
#  'N193',
#  'N194',
#  'N210',
#  'N211',
#  'N214',
#  'N215',
#  'N223',
#  'N226',
#  'N256',
#  'N257',
#  'N258',
#  'N268',
#  'N290',
#  'N293',
#  'N294',
#  'N302',
#  'N304',
#  'N306',
#  'N310',
#  'N311',
#  'N322',
#  'N325',
#  'N326',
#  'N329',
#  'N33',
#  'N330',
#  'N333',
#  'N336',
#  'N338',
#  'N350',
#  'N351',
#  'N353',
#  'N354',
#  'N356',
#  'N357',
#  'N358',
#  'N360',
#  'N363',
#  'N364',
#  'N365',
#  'N366',
#  'N367',
#  'N45',
#  'N5',
#  'N63',
#  'N64',
#  'N65',
#  'N66',
#  'N8',
#  'N92',
#  'N94',
#  'N96',
#  'N97',
#  'NEW01',
#  'ban hành kèm theo',
#  'bao gồm báo cáo',
#  'bao gồm bảo dưỡng',
#  'bao gồm bảo hành',
#  'bao gồm bảo đảm',
#  'bao gồm bố trí',
#  'bao gồm bổ sung',
#  'bao gồm chuyển',
#  'bao gồm chuyển giao',
#  'bao gồm chỉ định',
#  'bao gồm chứng nhận',
#  'bao gồm cung cấp',
#  'bao gồm công nhận',
#  'bao gồm di chuyển',
#  'bao gồm duyệt',
#  'bao gồm dựng',
#  'bao gồm ghi nhận',
#  'bao gồm giám sát',
#  'bao gồm giám sát thu',
#  'bao gồm giám định',
#  'bao gồm giải quyết',
#  'bao gồm huy động',
#  'bao gồm hỗ trợ',
#  'bao gồm kiểm soát',
#  'bao gồm kiểm soát thông qua',
#  'bao gồm kiểm tra',
#  'bao gồm kiểm tra quan trắc kiểm định',
#  'bao gồm kiểm định',
#  'bao gồm ký kết',
#  'bao gồm lập',
#  'bao gồm mua sắm',
#  'bao gồm ngăn chặn vi phạm',
#  'bao gồm nâng',
#  'bao gồm phát hiện',
#  'bao gồm phát hiện vi phạm',
#  'bao gồm quan trắc',
#  'bao gồm quản lý',
#  'bao gồm quản lý vận hành',
#  'bao gồm sử dụng',
#  'bao gồm sửa chữa',
#  'bao gồm sửa chữa kiểm định',
#  'bao gồm tham gia cứu',
#  'bao gồm tham gia phòng chống',
#  'bao gồm thay thế',
#  'bao gồm thiết kế',
#  'bao gồm thí nghiệm',
#  'bao gồm thông báo',
#  'bao gồm thử nghiệm',
#  'bao gồm thực hiện',
#  'bao gồm trao đổi',
#  'bao gồm triệu hồi',
#  'bao gồm truy tìm',
#  'bao gồm tổ chức',
#  'bao gồm vận hành',
#  'bao gồm xem xét',
#  'bao gồm xây dựng',
#  'bao gồm xử lý',
#  'bao gồm xử lý vi phạm',
#  'bao gồm đánh giá',
#  'bao gồm đóng góp',
#  'bao gồm đấu tranh phòng chống',
#  'bao gồm ứng dụng',
#  'bàn giao',
#  'báo hiệu chuẩn bị vượt',
#  'bảo dưỡng phải thực hiện',
#  'bảo trì theo',
#  'bảo trì vận hành',
#  'bảo trì vận hành khai thác',
#  'bắt buộc phải có',
#  'bắt buộc phải được thực hiện',
#  'bắt buộc phải được thực hiện theo',
#  'bị hư hỏng',
#  'bị làm',
#  'bị ngắt',
#  'bị thu hồi',
#  'bị truy cứu',
#  'bị tước',
#  'bị xử lý vi phạm',
#  'bốc dỡ',
#  'bồi dưỡng',
#  'bổ sung hoàn thiện',
#  'bổ sung được xem xét bổ sung theo',
#  'che khuất',
#  'chi trả',
#  'chi đáp ứng',
#  'chia sẻ',
#  'cho phép vào',
#  'chuyên dùng',
#  'chuyển hướng',
#  'chuyển đổi',
#  'chuẩn bị đầu tư',
#  'cháy chữa cháy',
#  'chăn thả',
#  'chằng buộc',
#  'chống',
#  'chống bỏ quên',
#  'chống vi phạm',
#  'chụp',
#  'chủ trì lập',
#  'chứng nhận thu hồi',
#  'cung ứng',
#  'còn',
#  'có gắn',
#  'có hiển thị',
#  'có phù hợp',
#  'có quy định',
#  'có vi phạm',
#  'có xảy xâm phạm',
#  'căn cứ quy định',
#  'cải tạo thành',
#  'cấm sử dụng',
#  'cấp còn',
#  'cấp phải mang',
#  'cấp phải phù hợp',
#  'cấp phải đính kèm theo',
#  'cấp theo quy định',
#  'cấp thuộc',
#  'cấp được đổi',
#  'cần huy động',
#  'cần thiết phải bố trí',
#  'cần thực hiện quy đổi',
#  'cần thực hiện quy đổi tính toán',
#  'cần thực hiện điều chỉnh',
#  'cần xác định',
#  'cần điều chỉnh bổ sung',
#  'cập nhật',
#  'cứu chữa đưa',
#  'cứu hộ có',
#  'cứu hộ khắc phục',
#  'cứu hộ phòng chống',
#  'cứu hộ phòng chống cháy',
#  'cứu hộ phải có',
#  'dàn',
#  'dừng bảo đảm',
#  'dừng khai thác sử dụng',
#  'dừng thu',
#  'dự kiến sử dụng',
#  'gia cường',
#  'giao quản lý',
#  'giao quản lý khai thác',
#  'giao theo quy định',
#  'giám sát kiểm tra',
#  'giám sát nghiệm thu',
#  'giám định',
#  'giơ',
#  'giải quyết khắc phục ùn tắc',
#  'giải quyết được thực hiện theo quy định',
#  'giảm thiểu',
#  'giảm tốc',
#  'gây cản trở',
#  'gồm báo cáo',
#  'gồm bảo dưỡng',
#  'gồm bảo vệ',
#  'gồm chuẩn bị nhận',
#  'gồm giám sát sửa chữa thay thế',
#  'gồm gửi',
#  'gồm khảo sát',
#  'gồm kiểm tra',
#  'gồm kiểm định',
#  'gồm lập',
#  'gồm quan trắc',
#  'gồm sửa chữa',
#  'gồm thẩm tra',
#  'gồm thực hiện',
#  'gồm trích nộp',
#  'gồm tổ chức',
#  'gồm vận hành',
#  'gồm xây dựng',
#  'gồm xử lý',
#  'gồm điều chỉnh',
#  'gồm đánh giá',
#  'gửi kèm',
#  'gửi nhận',
#  'hao phí',
#  'hiển thị',
#  'hiệu',
#  'huy động phù hợp',
#  'huy động tham gia phối hợp',
#  'hành nghề',
#  'hư hỏng dẫn sập đổ',
#  'hướng dẫn lập',
#  'hướng dẫn quản lý',
#  'hướng dẫn sử dụng',
#  'hướng dẫn xác định',
#  'hướng dẫn điều khiển',
#  'khai',
#  'khai thác bảo trì',
#  'khai thác sử dụng',
#  'khai thác được',
#  'khiếu nại',
#  'khám',
#  'khám nghiệm',
#  'khôi phục',
#  'khấu hao',
#  'khắc phục ùn tắc',
#  'khởi hành phải kiểm tra',
#  'khởi kiện',
#  'kinh doanh phải bao gồm',
#  'kinh doanh thuộc',
#  'kiến nghị',
#  'kiểm',
#  'kiểm giao dịch thu',
#  'kiểm tra xác định',
#  'kiểm tra xử lý',
#  'kiểm định',
#  'kiểm định quan trắc đánh giá',
#  'kiểm định sửa chữa bổ sung thay thế',
#  'kèm',
#  'kèm theo',
#  'kéo phải bảo đảm',
#  'kéo đẩy',
#  'ký kết',
#  'kết nối',
#  'liên quan bảo quản',
#  'liên quan thao tác sử dụng',
#  'là báo cáo',
#  'là bảo dưỡng',
#  'là bảo trì',
#  'là bảo vệ',
#  'là bảo đảm',
#  'là bảo đảm công khai',
#  'là chỉ huy',
#  'là chỉ đạo tổ chức thực hiện kiểm tra',
#  'là chịu',
#  'là cung cấp',
#  'là dừng',
#  'là giúp đỡ',
#  'là hướng dẫn',
#  'là hỗ trợ',
#  'là khai thác',
#  'là kiểm tra',
#  'là nhận',
#  'là phục vụ khai thác',
#  'là quan sát nắm',
#  'là quyết định',
#  'là quản lý',
#  'là quản lý vận hành khai thác',
#  'là sử dụng',
#  'là thông báo',
#  'là thực hiện',
#  'là thực hiện kiểm tra',
#  'là thực hiện quy định',
#  'là tuyên truyền',
#  'là tổ chức bảo trì',
#  'là tổ chức khai thác',
#  'là tổ chức quản lý',
#  'là tổ chức thực hiện',
#  'là vận động',
#  'là xử lý',
#  'là điều khiển',
#  'là điều tra',
#  'lưu hành chở',
#  'lưu hành phòng chống khắc phục',
#  'lạm dụng xâm phạm',
#  'lợi dụng xâm phạm',
#  'mang vác',
#  'miễn',
#  'miễn nộp',
#  'mãn',
#  'nghiệm thu',
#  'ngừng khai thác sử dụng',
#  'nhấp nháy',
#  'nhập tái xuất có',
#  'nhằm đảm bảo',
#  'nâng cấp',
#  'nêu',
#  'nộp thông qua',
#  'phá xử lý tiêu huỷ',
#  'phát hiện vi phạm',
#  'phát sinh',
#  'phát triển có',
#  'phân cấp',
#  'phân cấp uỷ quyền',
#  'phân cấp uỷ quyền quản lý',
#  'phân cấp uỷ quyền thực hiện',
#  'phân luồng',
#  'phân luồng phân',
#  'phân định',
#  'phép nhập khẩu có',
#  'phê duyệt',
#  'phê duyệt phù hợp quy định',
#  'phòng chống',
#  'phòng chống khắc phục',
#  'phòng chống vi phạm',
#  'phòng vệ',
#  'phải bao gồm',
#  'phải bàn giao',
#  'phải báo cáo',
#  'phải bảo dưỡng sửa chữa bảo đảm duy trì',
#  'phải bảo đảm',
#  'phải bảo đảm bao quát',
#  'phải bảo đảm bảo vệ',
#  'phải bảo đảm gây',
#  'phải bảo đảm hoạt động',
#  'phải bảo đảm kết nối',
#  'phải bảo đảm yêu cầu',
#  'phải bật',
#  'phải bồi thường quy định',
#  'phải che đậy',
#  'phải cho',
#  'phải chấp hành',
#  'phải chủ trì',
#  'phải cung cấp',
#  'phải còn',
#  'phải có',
#  'phải có quy định',
#  'phải cảnh báo',
#  'phải cập nhật',
#  'phải dừng',
#  'phải dừng bảo đảm',
#  'phải giảm',
#  'phải gây',
#  'phải gửi',
#  'phải khảo sát',
#  'phải kiến nghị',
#  'phải kiểm tra',
#  'phải kiểm tra xác định',
#  'phải kèm',
#  'phải là',
#  'phải làm ảnh hưởng',
#  'phải lập',
#  'phải lựa chọn',
#  'phải mang',
#  'phải mang theo',
#  'phải nhường',
#  'phải niêm yết',
#  'phải nối',
#  'phải nộp',
#  'phải phê duyệt',
#  'phải phù hợp',
#  'phải quan sát',
#  'phải quan sát bảo đảm',
#  'phải quan sát giảm',
#  'phải sử dụng',
#  'phải theo',
#  'phải theo quy định',
#  'phải thông báo',
#  'phải thẩm định',
#  'phải thể hiện',
#  'phải thực hiện',
#  'phải thực hiện báo cáo',
#  'phải thực hiện chuyển sang',
#  'phải thực hiện quan trắc',
#  'phải thực hiện theo',
#  'phải thực hiện theo quy định',
#  'phải tiến hành',
#  'phải tuân thủ',
#  'phải tuân thủ quy định vi phạm quy định',
#  'phải tắt',
#  'phải tổ chức hướng dẫn',
#  'phải tổ chức kiểm tra khảo sát đánh giá',
#  'phải tổ chức kiểm tra đánh giá',
#  'phải tổ chức kiểm tra đánh giá kiểm định',
#  'phải tổ chức lập',
#  'phải tổ chức phê duyệt',
#  'phải tổ chức quản lý',
#  'phải tổ chức thẩm định',
#  'phải tổ chức đánh giá',
#  'phải vào',
#  'phải xem xét chấp thuận theo quy định',
#  'phải đi',
#  'phải đi sát',
#  'phải đi theo',
#  'phải đáp ứng',
#  'phải được chằng buộc',
#  'phải được cấp',
#  'phải được giải quyết',
#  'phải được gắn',
#  'phải được quy định',
#  'phải được quản lý',
#  'phải được so sánh đánh giá',
#  'phải được sắp xếp',
#  'phải được thực hiện',
#  'phải được xác định',
#  'phải được điều tra',
#  'phải đảm bảo',
#  'phải đến trình báo',
#  'phải để',
#  'phải ưu tiên',
#  'phải ưu tiên hỗ trợ',
#  'phải ưu tiên khắc phục',
#  'phải ưu tiên sửa chữa',
#  'phải ưu tiên thực hiện',
#  'phải ở',
#  'quan trắc',
#  'quan trắc kiểm định',
#  'quy định',
#  'quy định báo cáo',
#  'quy định thực hiện',
#  'quy định thực hiện báo cáo',
#  'quy định thực hiện cung cấp',
#  'quy định xử lý',
#  'quyết định dừng thu',
#  'quyết định phê duyệt',
#  'quyết định đưa hoạt động',
#  'quản lý bảo trì',
#  'quản lý bảo trì kiểm định đánh giá',
#  'quản lý bảo trì vận hành',
#  'quản lý bảo trì vận hành khai thác',
#  'quản lý bảo vệ khai thác sử dụng',
#  'quản lý hoạt động',
#  'quản lý khai thác',
#  'quản lý khai thác sử dụng',
#  'quản lý sử dụng',
#  'quản lý theo',
#  'quản lý tập trung',
#  'quản lý vận hành',
#  'quản lý vận hành khai thác',
#  'quệt xuống đường',
#  'rà soát tổng hợp',
#  'rơi vãi xuống đường',
#  'so',
#  'soát',
#  'sát hạch',
#  'sản xuất hoạt động',
#  'sản xuất lắp ráp',
#  'sản xuất lắp ráp thuộc',
#  'sản xuất trưng bày giới thiệu',
#  'sập đổ',
#  'sử dụng nghiên cứu',
#  'sử dụng phục vụ',
#  'sử dụng theo quy định',
#  'sử dụng xử lý',
#  'sử dụng xử lý vi phạm',
#  'sử dụng được thực hiện',
#  'sử dụng được xác định',
#  'sửa chữa bảo trì sử dụng',
#  'sửa chữa khắc phục',
#  'sửa chữa ngăn ngừa',
#  'sửa đổi bổ sung',
#  'tham gia đấu giá',
#  'thay đổi so',
#  'theo hướng dẫn',
#  'theo quy định',
#  'thi công xây dựng',
#  'thiết kế lập',
#  'thiết kế thẩm tra thẩm định phê duyệt thi công giám sát',
#  'thu chi',
#  'thu gom',
#  'thu hồi theo quy định',
#  'thu thập lưu giữ khai thác',
#  'thu được điều chỉnh',
#  'thông',
#  'thông báo đạt',
#  'thấy bảo đảm',
#  'thấy bị đe doạ',
#  'thẩm định',
#  'thực hiện báo cáo',
#  'thực hiện bảo hành',
#  'thực hiện bảo trì',
#  'thực hiện bảo trì dẫn',
#  'thực hiện bảo trì theo quy định',
#  'thực hiện cấp',
#  'thực hiện cấp theo quy định',
#  'thực hiện kiểm',
#  'thực hiện kiểm tra',
#  'thực hiện quy định',
#  'thực hiện sửa đổi bổ sung thay đổi',
#  'thực hiện theo',
#  'thực hiện theo quy định',
#  'thực hiện theo quy định trừ',
#  'thực hiện thông qua quan trắc thí nghiệm kết hợp',
#  'thực hiện thẩm định',
#  'thực hiện tổ chức',
#  'thực hiện vận hành',
#  'thực hiện đảm bảo',
#  'thực hiện đối soát',
#  'thực hiện đổi',
#  'thực hiện đổi cấp',
#  'thực hiện đổi cấp theo quy định',
#  'thực hiện đổi theo',
#  'tiêu hao',
#  'tiến hành kiểm tra',
#  'tiến hành quản lý',
#  'tiếp nhận',
#  'tiếp tục chịu',
#  'tiếp tục có',
#  'tiếp tục điều khiển',
#  'trao đổi tặng cho thừa kế',
#  'trao đổi tặng cho để thừa kế',
#  'truyền dẫn',
#  'trình',
#  'trình bày theo',
#  'trích',
#  'trở xác định',
#  'trực',
#  'trực chốt',
#  'trực hệ thống',
#  'trực phân',
#  'trực sửa chữa',
#  'trực thu',
#  'trực thuộc',
#  'trực đảm bảo',
#  'tuyên truyền giảm',
#  'tuyên truyền giảm thiểu',
#  'tuần kiểm',
#  'tuần tra kiểm soát',
#  'tuần tra kiểm soát phải tuân thủ',
#  'tuỳ theo',
#  'tác nghiệp',
#  'tái xuất',
#  'tìm kiếm cứu',
#  'tạm trú',
#  'tổ chức bàn giao',
#  'tổ chức bốc dỡ',
#  'tổ chức cân',
#  'tổ chức kiểm tra',
#  'tổ chức kiểm định',
#  'tổ chức lập',
#  'tổ chức lập phê duyệt',
#  'tổ chức nghiệm thu',
#  'tổ chức phê duyệt',
#  'tổ chức quản lý vận hành khai thác',
#  'tổ chức thu',
#  'tổ chức thẩm định',
#  'tổ chức thực hiện',
#  'tổ chức thực hiện bảo trì',
#  'tổ chức thực hiện kiểm tra',
#  'tổ chức thực hiện sử dụng',
#  'tổ chức thực hiện sửa chữa',
#  'tổ chức trình',
#  'tổ chức trình duyệt',
#  'tổ chức tuần tra kiểm tra',
#  'tổ chức tập huấn',
#  'tổ chức đảm bảo',
#  'tổ chức đấu thầu',
#  'tổ chức đặt hàng',
#  'uỷ quyền',
#  'vi phạm ảnh hưởng',
#  'vận hành khai thác',
#  'vận hành khai thác bảo trì',
#  'vận hành quản lý thu',
#  'vận hành được quy định',
#  'xem xét quyết định',
#  'xem xét thoả thuận bổ sung',
#  'xuất',
#  'xác nhận có',
#  'xác định quy định',
#  'xác định theo',
#  'xác định theo quy định',
#  'xây dựng cải tạo nâng cấp mở rộng sửa chữa',
#  'xây dựng phục vụ khai thác',
#  'xây dựng thực hiện',
#  'xây dựng thực hiện theo quy định',
#  'xây dựng xác định',
#  'xảy',
#  'xếp hàng hoá',
#  'xử lý',
#  'xử lý khắc phục',
#  'xử lý vi phạm',
#  'xử lý vi phạm giải toả tháo dỡ',
#  'xử lý ùn tắc',
#  'yêu cầu báo cáo',
#  'áp dụng theo',
#  'áp dụng theo quy định',
#  'áp giải',
#  'ùn tắc',
#  'đi làm',
#  'đi tránh',
#  'điều chỉnh bổ sung',
#  'điều khiển báo hiệu',
#  'điều tiết phân',
#  'điều tra giải quyết',
#  'đo đạc',
#  'đu bám',
#  'đón',
#  'đôn đốc',
#  'đăng kiểm',
#  'đăng ký cấp',
#  'được ban hành kèm theo',
#  'được buông',
#  'được bãi bỏ',
#  'được bảo trì',
#  'được bịt mắt điều khiển',
#  'được bố trí',
#  'được bổ sung',
#  'được chi',
#  'được chi hỗ trợ',
#  'được chia sẻ',
#  'được cho',
#  'được chở',
#  'được cấp quy định',
#  'được cấp sang',
#  'được cấp thành',
#  'được duyệt vượt quá',
#  'được dẫn dắt',
#  'được giữ',
#  'được gọi',
#  'được gửi',
#  'được hoàn trả',
#  'được hình thành',
#  'được khắc phục',
#  'được kéo',
#  'được kéo theo',
#  'được kết cấu thực hiện',
#  'được kết nối',
#  'được lưu trữ',
#  'được lập',
#  'được lập căn cứ',
#  'được lắp đặt',
#  'được miễn nộp',
#  'được ngồi',
#  'được nhận',
#  'được nêu',
#  'được nối',
#  'được nộp',
#  'được phân cấp uỷ quyền quản lý',
#  'được phân cấp uỷ quyền thực hiện',
#  'được phân cấp uỷ quyền tổ chức thực hiện',
#  'được phân loại',
#  'được phân loại gồm',
#  'được phân loại thành',
#  'được phép lưu hành',
#  'được phép lưu hành thực hiện',
#  'được phê duyệt',
#  'được phê duyệt phù hợp',
#  'được qua',
#  'được quy định',
#  'được quản lý',
#  'được rẽ',
#  'được sản xuất chế tạo',
#  'được sản xuất hoạt động',
#  'được sửa chữa',
#  'được sửa đổi bổ sung',
#  'được thiết kế',
#  'được thiết kế hoạt động',
#  'được thiết kế sản xuất hoạt động',
#  'được thành lập',
#  'được thể hiện',
#  'được thực hiện theo',
#  'được thực hiện theo quy định',
#  'được thực hiện thông qua',
#  'được thực hiện thông qua quan trắc thí nghiệm kết hợp',
#  'được tiếp tục sử dụng điều khiển',
#  'được tiếp tục điều khiển',
#  'được trả',
#  'được trả thêm',
#  'được tính',
#  'được vượt',
#  'được vượt quy định',
#  'được xem xét thay đổi',
#  'được xác định',
#  'được xác định căn cứ',
#  'được xác định quy định',
#  'được xác định theo quy định',
#  'được xác định xác định',
#  'được xây dựng lắp đặt',
#  'được xây dựng theo quy định',
#  'được yêu cầu',
#  'được áp dụng',
#  'được áp dụng theo',
#  'được đi',
#  'được điều chỉnh',
#  'được điều chỉnh bổ sung',
#  'được điều khiển',
#  'được đấu giá',
#  'được đổi',
#  'được đổi cấp sang',
#  'được đổi sang',
#  'được đứng',
#  'được ưu tiên',
#  'được ở',
#  'đạt',
#  'đấu giá',
#  'đấu giá bị thu hồi',
#  'đấu giá gắn',
#  'đấu giá phải thực hiện',
#  'đấu giá được thực hiện',
#  'đấu giá được đấu giá',
#  'đấu thầu cung cấp',
#  'đầu tư có',
#  'đầu tư xây dựng',
#  'đặt hàng đấu thầu cung cấp',
#  'đếm thực hiện theo',
#  'đề nghị xem xét thoả thuận bổ sung',
#  'để rơi vãi',
#  'để xảy',
#  'định hình',
#  'đối soát giao dịch',
#  'đối soát giao dịch dừng',
#  'đổ ách tắc',
#  'ưu tiên']

# %%
import os

def export_concept_names_to_txt(session, output_path="concepts.txt"):
    """
    Export all unique concept node names (c.name) from Neo4j to a text file.
    Each line in the file will contain one concept name.
    """
    with session.begin_transaction() as tx:
        result = tx.run("""
            MATCH (c:Concept)
            WHERE c.name IS NOT NULL
            RETURN DISTINCT c.name AS concept_name
            ORDER BY c.name
        """)
        concept_names = [record["concept_name"] for record in result]

    # Write to file
    directory = os.path.dirname(output_path)
    if directory:
        os.makedirs(directory, exist_ok=True)
    with open(output_path, "w", encoding="utf-8") as f:
        for name in concept_names:
            f.write(name.strip() + "\n")

    print(f"✅ Exported {len(concept_names)} unique concept names to {output_path}")

    return concept_names

# %%
export_concept_names_to_txt(neo4j_session, "concept_names.txt")
# Out:
# ✅ Exported 4023 unique concept names to concept_names.txt
# ['A153',
#  'A19',
#  'A32',
#  'B167',
#  'B169',
#  'B177',
#  'B179',
#  'C10',
#  'C100',
#  'C105',
#  'C160',
#  'C181',
#  'C182',
#  'C188',
#  'C194',
#  'C2',
#  'C228',
#  'C293',
#  'C71',
#  'C78',
#  'C79',
#  'C8',
#  'C83',
#  'C84',
#  'C85',
#  'D108',
#  'D28',
#  'D3',
#  'D65',
#  'E134',
#  'F120',
#  'F14',
#  'F207',
#  'F263',
#  'F273',
#  'F275',
#  'F278',
#  'F66',
#  'F8',
#  'G126',
#  'G148',
#  'G154',
#  'G163',
#  'G164',
#  'G179',
#  'G191',
#  'G194',
#  'G196',
#  'G230',
#  'G267',
#  'G281',
#  'G285',
#  'G293',
#  'G43',
#  'G63',
#  'G71',
#  'G72',
#  'G89',
#  'G9',
#  'H112',
#  'H113',
#  'H185',
#  'H213',
#  'H230',
#  'H30',
#  'H38',
#  'H4',
#  'H42',
#  'H43',
#  'H5',
#  'H67',
#  'H73',
#  'H83',
#  'H90',
#  'I10',
#  'I101',
#  'I133',
#  'I136',
#  'I140',
#  'I141',
#  'I2',
#  'I3',
#  'I42',
#  'I43',
#  'I45',
#  'I7',
#  'I70',
#  'I73',
#  'J114',
#  'J138',
#  'J157',
#  'J182',
#  'J210',
#  'J219',
#  'J220',
#  'J225',
#  'J226',
#  'J227',
#  'J228',
#  'J229',
#  'J231',
#  'J235',
#  'J33',
#  'J35',
#  'J41',
#  'J47',
#  'J60',
#  'J80',
#  'J82',
#  'K205',
#  'K32',
#  'K59',
#  'K71',
#  'K79',
#  'K84',
#  'L10',
#  'L106',
#  'L144',
#  'L145',
#  'L151',
#  'L174',
#  'L179',
#  'L207',
#  'L226',
#  'L233',
#  'L242',
#  'L259',
#  'L264',
#  'L267',
#  'L29',
#  'L32',
#  'L34',
#  'L36',
#  'L54',
#  'L83',
#  'L84',
#  'M103',
#  'M106',
#  'M107',
#  'M109',
#  'M120',
#  'M123',
#  'M125',
#  'M126',
#  'M129',
#  'M131',
#  'M132',
#  'M135',
#  'M136',
#  'M15',
#  'M152',
#  'M157',
#  'M159',
#  'M16',
#  'M164',
#  'M18',
#  'M189',
#  'M19',
#  'M209',
#  'M213',
#  'M221',
#  'M52',
#  'M75',
#  'M76',
#  'M80',
#  'M83',
#  'M91',
#  'M93',
#  'M94',
#  'M96',
#  'M97',
#  'N101',
#  'N110',
#  'N127',
#  'N133',
#  'N14',
#  'N152',
#  'N153',
#  'N165',
#  'N167',
#  'N17',
#  'N18',
#  'N183',
#  'N190',
#  'N193',
#  'N194',
#  'N213',
#  'N219',
#  'N221',
#  'N223',
#  'N227',
#  'N228',
#  'N230',
#  'N235',
#  'N255',
#  'N257',
#  'N258',
#  'N269',
#  'N275',
#  'N293',
#  'N3',
#  'N302',
#  'N303',
#  'N304',
#  'N305',
#  'N308',
#  'N311',
#  'N327',
#  'N333',
#  'N335',
#  'N336',
#  'N351',
#  'N357',
#  'N365',
#  'N366',
#  'N367',
#  'N37',
#  'N44',
#  'N45',
#  'N5',
#  'N54',
#  'N6',
#  'N61',
#  'N66',
#  'N7',
#  'N8',
#  'N80',
#  'N89',
#  'N91',
#  'N94',
#  'N99',
#  'NEW01',
#  'an ninh quốc gia',
#  'an ninh trật tự an toàn giao thông đường bộ',
#  'an ninh trật tự theo',
#  'an ninh tuyến giao thông đường bộ',
#  'an toàn bến xe',
#  'an toàn chợ',
#  'an toàn công trình',
#  'an toàn công trình công cộng tập trung đông người',
#  'an toàn công trình quá trình khai thác',
#  'an toàn giao thông',
#  'an toàn giao thông an toàn công trình',
#  'an toàn giao thông công trình đường bộ khai thác',
#  'an toàn giao thông xảy tuyến đường trung ương',
#  'an toàn giao thông đường',
#  'an toàn giao thông đường bộ',
#  'an toàn hiện trường vụ tai nạn giao thông đường bộ',
#  'an toàn khai thác',
#  'an toàn khi',
#  'an toàn khi vận hành',
#  'an toàn khu vực',
#  'an toàn khu vực thi công đường bộ',
#  'an toàn khu vực tổ chức',
#  'an toàn khu vực đông dân cư',
#  'an toàn kỹ thuật',
#  'an toàn nơi',
#  'an toàn nơi trên',
#  'an toàn nơi đó',
#  'an toàn quá trình khai thác',
#  'an toàn sử dụng',
#  'an toàn sử dụng an toàn',
#  'an toàn trường hợp',
#  'an toàn trường hợp sau đây',
#  'an toàn trường hợp đó',
#  'an toàn vận hành',
#  'ban chỉ huy phòng chống thiên tai',
#  'ban ngày khi',
#  'ban đầu thực hiện công việc đó',
#  'barie trạm',
#  'biên bản nghiệm thu có',
#  'biên bản nghiệm thu hoàn thành công trình đưa khai thác',
#  'biến dạng công trình đường bộ',
#  'biến dạng nghiêng lún nứt chuyển vị',
#  'biển báo',
#  'biển báo hiệu',
#  'biển báo hiệu chỉ dẫn',
#  'biển báo hiệu đường bộ',
#  'biển số xe',
#  'biển số xe cơ giới',
#  'biển số xe cơ giới xe máy chuyên dùng',
#  'biển số xe cơ giới xe máy chuyên dùng trường hợp biển số xe bị mờ hỏng',
#  'biển số xe loại khác',
#  'biển số xe nền màu trắng',
#  'biển số xe nền màu trắng chữ',
#  'biển số xe nền màu trắng chữ màu đỏ số màu đen',
#  'biển số xe nền màu vàng chữ',
#  'biển số xe nền màu xanh chữ',
#  'biển số xe nền màu đỏ',
#  'biển số xe quy định điểm khoản điều',
#  'biển số xe quy định điểm khoản điều này',
#  'biển số xe theo',
#  'biển số xe theo mã định danh',
#  'biển số xe thời hạn tháng ngày',
#  'biển số xe trúng',
#  'biển số xe trúng đấu giá',
#  'biển số xe tạm thời khi phải',
#  'biển số xe tạm thời trường hợp quy định điều luật này',
#  'biển số xe đúng quy định pháp luật',
#  'biển số xe được',
#  'biển số đăng ký',
#  'biểu hiện xuống cấp bảo đảm an toàn',
#  'biểu hiện xuống cấp ảnh hưởng an toàn',
#  'biểu hiện xuống cấp ảnh hưởng an toàn sử dụng',
#  'biểu mẫu điện tử',
#  'biểu mẫu điện tử bản',
#  'biểu mẫu điện tử bản kê linh kiện chính sử dụng',
#  'biểu mẫu điện tử giấy đề nghị',
#  'biểu mẫu điện tử giấy đề nghị mẫu số phụ lục ban hành',
#  'biểu mẫu điện tử giấy đề nghị thẩm định thiết kế',
#  'biểu mẫu điện tử khi người',
#  'biểu mẫu điện tử trường hợp nộp',
#  'biểu mẫu điện tử trường hợp nộp thông qua hệ thống dịch vụ công trực tuyến',
#  'biểu mẫu điện tử trường hợp nộp thông qua hệ thống dịch vụ công trực tuyến bản',
#  'biểu mẫu điện tử văn bản đề nghị',
#  'biện pháp bảo vệ mặt đường',
#  'biện pháp bảo đảm an toàn giao thông đường bộ',
#  'biện pháp giải quyết thẩm quyền',
#  'biện pháp khắc phục',
#  'biện pháp khắc phục cơ quan',
#  'biện pháp khắc phục kịp thời',
#  'biện pháp nghiệp vụ theo',
#  'biện pháp ngăn chặn theo',
#  'biện pháp phòng ngừa',
#  'biện pháp sau đây',
#  'biện pháp sửa chữa',
#  'biện pháp xử lý',
#  'biện pháp xử lý kịp thời quá trình khai thác',
#  'biện pháp đảm bảo an toàn giao thông công trình',
#  'biện pháp đảm bảo giao thông khẩn cấp tuyến đường',
#  'bom mìn vật liệu',
#  'bánh chạy động cơ',
#  'bánh trở',
#  'báo cáo báo cáo tình hình hoạt động',
#  'báo cáo báo cáo định kỳ tháng cuối năm',
#  'báo cáo báo cáo định kỳ tháng đầu năm',
#  'báo cáo bộ giao thông vận tải ngày tháng kỳ báo cáo báo cáo định kỳ tháng cuối năm',
#  'báo cáo bộ giao thông vận tải ngày tháng kỳ báo cáo báo cáo định kỳ tháng đầu năm',
#  'báo cáo công tác phòng',
#  'báo cáo công tác quản lý',
#  'báo cáo cơ quan',
#  'báo cáo cấp',
#  'báo cáo doanh thu dịch vụ',
#  'báo cáo dịch vụ bưu chính cơ quan',
#  'báo cáo dữ liệu phân tích',
#  'báo cáo fax',
#  'báo cáo fax cơ quan',
#  'báo cáo hoạt động trạm',
#  'báo cáo hàng năm',
#  'báo cáo hàng năm ngày tháng kỳ báo cáo',
#  'báo cáo hình thức văn bản giấy',
#  'báo cáo hệ thống thư điện tử cơ quan',
#  'báo cáo kinh tế kỹ thuật',
#  'báo cáo kinh tế kỹ thuật sửa chữa công trình',
#  'báo cáo kinh tế kỹ thuật đầu tư',
#  'báo cáo kiểm tra',
#  'báo cáo kết quả',
#  'báo cáo kết quả kiểm định',
#  'báo cáo kết quả quan trắc',
#  'báo cáo kết quả thử nghiệm chất lượng an toàn kỹ thuật',
#  'báo cáo kết quả thử nghiệm cơ sở thử nghiệm',
#  'báo cáo nghiên cứu khả thi dự án',
#  'báo cáo nghiên cứu khả thi dự án đầu tư theo phương thức ppp',
#  'báo cáo nghiên cứu khả thi đầu tư',
#  'báo cáo năm',
#  'báo cáo phương thức',
#  'báo cáo phương thức fax',
#  'báo cáo phương thức gửi trực tiếp',
#  'báo cáo phương thức khác quy định pháp luật cơ quan',
#  'báo cáo phương thức khác theo',
#  'báo cáo phương thức khác theo quy định pháp luật cơ quan',
#  'báo cáo phương thức phương thức khác theo',
#  'báo cáo phương thức quy định',
#  'báo cáo phương thức sau',
#  'báo cáo sở giao thông vận tải',
#  'báo cáo theo mẫu biểu số liệu báo cáo',
#  'báo cáo tháng đầu năm',
#  'báo cáo thời gian',
#  'báo cáo thử nghiệm thể hiện kiểu loại linh kiện nhập khẩu',
#  'báo cáo trực tiếp cơ quan',
#  'báo cáo tên',
#  'báo cáo tình hình',
#  'báo cáo tình hình hoạt động',
#  'báo cáo tình hình hoạt động vận tải đường bộ địa phương',
#  'báo cáo tần suất định kỳ tháng',
#  'báo cáo việc',
#  'báo cáo việc quản lý',
#  'báo cáo được thể hiện hình thức văn bản giấy',
#  'báo cáo định kỳ hàng năm',
#  'báo cáo định kỳ hàng quý',
#  'báo cáo định kỳ hàng quý ngày tháng cuối quý',
#  'báo cáo định kỳ hàng quý tình hình chất lượng công trình đường bộ được',
#  'báo cáo định kỳ hàng tháng',
#  'báo cáo định kỳ quý',
#  'báo cáo định kỳ tháng cuối năm',
#  'báo cáo định kỳ tháng cuối năm ngày tháng năm tiếp theo',
#  'báo cáo định kỳ tháng đầu năm',
#  'báo cáo định kỳ tháng đầu năm ngày tháng kỳ báo cáo',
#  'báo hiệu biển báo',
#  'báo hiệu cảnh báo nguy hiểm',
#  'báo hiệu khác dành người',
#  'báo hiệu màu đỏ điểm cuối cùng hàng hoá',
#  'báo hiệu màu đỏ điểm đầu',
#  'báo hiệu màu đỏ điểm đầu hàng hoá',
#  'báo hiệu đường bộ',
#  'báo hiệu đường bộ theo thứ tự ưu tiên trên dưới',
#  'bên giao',
#  'bên liên quan',
#  'bên nhận',
#  'bình đồ duỗi thẳng',
#  'băng ghi hình tình trạng công trình',
#  'bản cam kết cơ sở sản xuất việc kiểu loại xe đề nghị',
#  'bản cam kết việc kiểu loại sản phẩm kiểm tra',
#  'bản cam kết việc kiểu loại xe đề nghị',
#  'bản chính',
#  'bản chính hồ sơ trường hợp',
#  'bản chính hồ sơ đăng ký',
#  'bản chính khi nộp trực tiếp',
#  'bản chính trường hợp',
#  'bản chính trường hợp nộp trực tiếp',
#  'bản chính tài liệu hướng dẫn',
#  'bản chính tài liệu sau',
#  'bản chính tài liệu thiết kế trường hợp nộp trực tiếp',
#  'bản dạng điện tử',
#  'bản dạng điện tử hồ sơ đăng ký',
#  'bản dạng điện tử trường hợp nộp',
#  'bản dạng điện tử trường hợp nộp thông qua hệ thống dịch vụ công trực tuyến',
#  'bản dạng điện tử trường hợp nộp thông qua hệ thống dịch vụ công trực tuyến bản vẽ kỹ thuật kèm thông số sản phẩm',
#  'bản gốc bản vẽ hoàn công',
#  'bản gốc giấy biên nhận còn hiệu lực chi nhánh ngân hàng nước ngoài',
#  'bản gốc giấy biên nhận còn hiệu lực trường hợp xe được',
#  'bản gốc giấy biên nhận còn hiệu lực tổ chức tín dụng',
#  'bản gốc giấy tờ xác nhận tổ chức tín dụng',
#  'bản hồ sơ thiết kế trường hợp cơ sở thiết kế khác cơ sở sản xuất',
#  'bản hồ sơ thiết kế trường hợp cơ sở thiết kế là cơ sở sản xuất',
#  'bản kê linh kiện chính sử dụng',
#  'bản kê linh kiện chính sử dụng lắp ráp động cơ',
#  'bản sao có',
#  'bản sao có xác nhận cơ sở sản xuất',
#  'bản sao có xác thực',
#  'bản sao có xác thực cơ sở thiết kế được',
#  'bản sao giấy',
#  'bản sao giấy đề nghị thẩm định thiết kế mẫu phụ lục ban hành',
#  'bản sao hồ sơ',
#  'bản sao trường hợp',
#  'bản sao tài liệu',
#  'bản sao điện tử',
#  'bản sao điện tử có giá trị pháp lý',
#  'bản sao điện tử có giá trị pháp lý khi nộp',
#  'bản sao điện tử có giá trị pháp lý trường hợp nộp',
#  'bản sao điện tử cơ sở thiết kế',
#  'bản sao điện tử giấy chứng nhận thẩm định thiết kế',
#  'bản sao điện tử hồ sơ',
#  'bản sao điện tử trường hợp',
#  'bản sao điện tử trường hợp nộp',
#  'bản thuyết minh',
#  'bản thuyết minh ký hiệu số đóng sản phẩm',
#  'bản thuyết minh thiết kế kỹ thuật',
#  'bản thông số tính năng kỹ thuật tổng thành hệ thống liên quan nội dung tính toán thiết kế',
#  'bản thống kê tổng thành hệ thống sản xuất nước',
#  'bản tính bản vẽ thuyết minh',
#  'bản tính bản vẽ thuyết minh theo',
#  'bản tính hồ sơ thiết kế',
#  'bản vẽ hoàn công',
#  'bản vẽ hồ sơ thiết kế',
#  'bản vẽ kỹ thuật',
#  'bản vẽ kỹ thuật hồ sơ thiết kế được cơ quan',
#  'bản vẽ thi công',
#  'bản điện tử bản thuyết minh thiết kế kỹ thuật',
#  'bản điện tử bản vẽ kỹ thuật hồ sơ thiết kế',
#  'bản đăng ký',
#  'bảng mục phụ lục này',
#  'bảng trên cơ quan nhà nước',
#  'bảo hiểm thất nghiệp',
#  'bảo hiểm xã hội bảo hiểm y tế bảo hiểm thất nghiệp',
#  'bảo hiểm xã hội bảo hiểm y tế bảo hiểm thất nghiệp kinh phí công đoàn',
#  'bảo hiểm y tế',
#  'bảo vệ môi trường',
#  'bất hợp lý tổ chức giao thông cơ quan cảnh sát giao thông',
#  'bến người',
#  'bến người được',
#  'bến phà',
#  'bến phà cầu phao hầm đường bộ',
#  'bến phà đường bộ',
#  'bến phà đường bộ hệ thống quốc lộ',
#  'bến phương tiện giao thông đường bộ',
#  'bến xe khách',
#  'bệnh từng hạng giấy phép lái xe',
#  'bộ giao thông',
#  'bộ giao thông vận tải',
#  'bộ giao thông vận tải phê duyệt',
#  'bộ giao thông vận tải phê duyệt kế hoạch bảo trì điều chỉnh',
#  'bộ giao thông vận tải tổng cục đường bộ việt nam',
#  'bộ hồ sơ',
#  'bộ hồ sơ cơ quan',
#  'bộ hồ sơ kỹ thuật',
#  'bộ hồ sơ kỹ thuật bản sao',
#  'bộ hồ sơ thiết kế',
#  'bộ hồ sơ thiết kế theo',
#  'bộ hồ sơ thiết kế trường hợp',
#  'bộ hồ sơ thiết kế đầy đủ',
#  'bộ hồ sơ đăng ký',
#  'bộ hồ sơ đề nghị',
#  'bộ khi',
#  'bộ luật này',
#  'bộ luật số',
#  'bộ ngành',
#  'bộ phận công trình',
#  'bộ phận công trình bị',
#  'bộ phận công trình mình thiết kế cùng hồ sơ thiết kế',
#  'bộ phận công trình đường bộ khác thiết kế',
#  'bộ phận gián tiếp',
#  'bộ phận gián tiếp đơn vị',
#  'bộ phận hạng mục công trình',
#  'bộ phận hạng mục kết cấu thiết bị',
#  'bộ phận lao động trực tiếp',
#  'bộ phận liên quan',
#  'bộ phận liên quan ca trực được',
#  'bộ qua đường',
#  'bộ trưởng bộ công an',
#  'bộ trưởng bộ giao thông vận tải',
#  'bộ trưởng bộ xây dựng',
#  'bộ tài chính',
#  'bộ tài liệu theo',
#  'bộ tài liệu thiết kế dạng điện tử',
#  'bộ xe lăn người khuyết tật',
#  'bộ xây dựng',
#  'bộ được',
#  'bụi bẩn suốt quá trình vận chuyển đường',
#  'ca khoảng thời gian sau khi',
#  'ca làm việc',
#  'ca làm việc bình thường đêm',
#  'ca làm việc đơn vị',
#  'camera giám sát điều hoà không khí',
#  'cao hơn',
#  'cao năng lực lực lượng',
#  'cbtctdd năm',
#  'cbthtkt năm',
#  'cbtnăm tổng chi phí',
#  'cbtvd',
#  'chi nhánh ngân hàng nước ngoài',
#  'chi phí bảo dưỡng',
#  'chi phí bảo trì',
#  'chi phí bảo trì hạng mục công trình dân dụng năm',
#  'chi phí bảo trì khác năm cộng chi phí',
#  'chi phí bảo trì năm',
#  'chi phí bảo trì năm có thay thế thiết bị',
#  'chi phí bảo trì năm tính toán',
#  'chi phí bảo trì thứ thời hạn hợp đồng dự án',
#  'chi phí bảo trì vòng đời',
#  'chi phí bảo trì vòng đời công trình trạm',
#  'chi phí bộ phận gián tiếp theo',
#  'chi phí bộ phận phục vụ gián tiếp khác',
#  'chi phí cần thiết khác',
#  'chi phí dự phòng yếu tố trượt giá giai đoạn vận hành khai thác',
#  'chi phí dự án',
#  'chi phí hạng mục an toàn giao thông',
#  'chi phí hội họp',
#  'chi phí khi cần thiết',
#  'chi phí khác',
#  'chi phí khác liên quan',
#  'chi phí kiểm toán thẩm tra',
#  'chi phí liên quan khác theo',
#  'chi phí mua sắm',
#  'chi phí máy móc thiết bị văn phòng',
#  'chi phí mục này người',
#  'chi phí nhân công theo hệ số bình quân',
#  'chi phí nhân công trực tiếp',
#  'chi phí này',
#  'chi phí phần này',
#  'chi phí quy định điểm khoản điều nghị định số',
#  'chi phí quản lý',
#  'chi phí quản lý bảo trì vận hành công trình đường bộ',
#  'chi phí quản lý bảo trì vận hành công trình đường bộ sử dụng vốn nhà nước',
#  'chi phí quản lý chủ sở hữu',
#  'chi phí quản lý vận hành khai thác',
#  'chi phí quản lý vận hành khai thác bảo trì công trình',
#  'chi phí rà',
#  'chi phí sửa chữa',
#  'chi phí thiết bị',
#  'chi phí thiết bị lắp đặt hạng mục công trình hạ tầng kỹ thuật',
#  'chi phí thông tin',
#  'chi phí thực hiện',
#  'chi phí thực hiện bảo trì kế hoạch bảo trì hàng năm',
#  'chi phí thực hiện công tác sau',
#  'chi phí thực hiện công việc bảo trì',
#  'chi phí thực hiện công việc bảo trì quản lý',
#  'chi phí thực hiện công việc bảo trì quản lý vận hành công trình',
#  'chi phí tiền lương',
#  'chi phí tiền lương chi phí nhân công giá đơn giá sản phẩm dịch vụ công sử dụng kinh phí ngân sách nhà nước doanh nghiệp',
#  'chi phí trực tiếp thực hiện',
#  'chi phí tư vấn',
#  'chi phí tư vấn phục vụ',
#  'chi phí tư vấn phục vụ bảo trì công trình đường bộ quy định',
#  'chi phí tư vấn phục vụ bảo trì công trình đường bộ theo quy định',
#  'chi phí văn phòng phẩm',
#  'chi phí vận hành',
#  'chi phí vận hành khai thác công trình đường bộ',
#  'chi phí xây dựng',
#  'chi phí đi lại',
#  'chi phí điện nước',
#  'chi phí đào tạo nâng cao trình độ nhân viên',
#  'chi phí đó chi phí vận hành ca ngày làm việc',
#  'chi phí đúng quy định nhà nước',
#  'chi phí đầu tư',
#  'chi phí đền bù',
#  'chi phí địa bàn',
#  'chi phí đồng phục nhân viên',
#  'chi tiết quy phạm tiêu chuẩn quy chuẩn kỹ thuật',
#  'chiều cao lớn',
#  'chiều cao tối đa hàng hoá phải',
#  'chiều rộng đủ làn xe cơ giới',
#  'chuyên môn',
#  'chuyển vị công trình đường bộ',
#  'chân chống',
#  'chính quyền địa phương nơi gần chủ sở hữu',
#  'chính đáng theo',
#  'chướng ngại vật phía trước',
#  'chướng ngại vật đường',
#  'chất kích thích khác',
#  'chất lượng',
#  'chất lượng an toàn kiểu loại xe',
#  'chất lượng an toàn kỹ thuật',
#  'chất lượng bảo trì',
#  'chất lượng công trình',
#  'chất lượng công trình phục vụ công tác bảo trì',
#  'chất lượng công trình vào',
#  'chất lượng công trình xây dựng',
#  'chất lượng công trình đường bộ',
#  'chất lượng công tác',
#  'chất lượng công tác bảo dưỡng được',
#  'chất lượng công tác bảo trì theo đúng quy định pháp luật',
#  'chất lượng cơ sở sản xuất',
#  'chất lượng cơ sở sản xuất còn hiệu lực',
#  'chất lượng giai đoạn vận hành',
#  'chất lượng hiện trạng công trình',
#  'chất lượng hiện trạng công trình phục vụ việc',
#  'chất lượng hình thức trực tiếp hình thức',
#  'chất lượng kiểu loại cơ quan nhà nước',
#  'chất lượng nhập khẩu mẫu quy định phụ lục iiic kèm thông tư này',
#  'chất lượng phục vụ công tác',
#  'chất lượng sản phẩm xây dựng bộ phận công trình đường bộ',
#  'chất lượng theo',
#  'chất lượng xuất xưởng',
#  'chất đó người',
#  'chế độ báo cáo',
#  'chế độ báo cáo theo',
#  'chế độ báo cáo tổng cục đường bộ việt nam',
#  'chế độ người lao động bộ phận gián tiếp',
#  'chế độ người lao động bộ phận gián tiếp theo',
#  'chỉ dẫn hướng dẫn tư vấn thiết kế nhà cung cấp thiết bị công nghệ',
#  'chỉ dẫn hướng dẫn đó',
#  'chỉ dẫn kỹ thuật thi công',
#  'chỉ dẫn kỹ thuật vận hành',
#  'chỉ dẫn nhà sản xuất',
#  'chỉ huy ca',
#  'chỉ số nhám',
#  'chỉ tiêu kỹ thuật',
#  'chỗ người lái xe',
#  'chỗ người lái xe chỗ',
#  'chủ phương tiện',
#  'chủ sở hữu',
#  'chủ sở hữu công trình',
#  'chủ sở hữu công trình đường bộ',
#  'chủ sở hữu xe',
#  'chủ thể liên quan quá trình vận hành khai thác bảo trì công trình đường bộ',
#  'chủ trương danh mục bổ sung thực hiện công việc quy định điểm khoản điều này',
#  'chủ xe',
#  'chủ xe cơ giới xe máy chuyên dùng',
#  'chủ xe đề nghị',
#  'chủ đầu tư',
#  'chủ đầu tư nhà thầu thi công',
#  'chủ đầu tư đơn vị liên quan',
#  'chức năng công dụng đặc biệt',
#  'chức năng cảnh báo',
#  'chức năng khi',
#  'chức năng đặc biệt',
#  'chứng minh thư công vụ cơ quan',
#  'chứng minh thư ngoại giao cơ quan đó',
#  'chứng minh thư ngoại giao tổ chức đó',
#  'chứng nhận chất lượng an toàn kỹ thuật',
#  'chứng nhận đăng ký xe',
#  'chứng từ',
#  'chứng từ xuất',
#  'cuối ca',
#  'cá nhân khác',
#  'cá nhân liên quan',
#  'cá nhân liên quan công tác',
#  'cá nhân liên quan vụ tai nạn giao thông đường bộ',
#  'cá nhân quy định điểm a',
#  'cá nhân thực hiện kiểm định',
#  'cá nhân thực hiện quan trắc công trình',
#  'cá nhân trúng',
#  'cách thức thực hiện',
#  'cách thức trình tự nội dung quản lý',
#  'cán bộ nhân viên',
#  'có làn đường giảm tốc người',
#  'có quy trình bảo trì',
#  'công cụ hỗ trợ',
#  'công dụng đặc biệt',
#  'công nghệ liên quan trật tự an toàn giao thông đường bộ',
#  'công nghệ phục vụ',
#  'công nhân làm nhiệm vụ duy tu',
#  'công năng',
#  'công suất',
#  'công suất động cơ',
#  'công suất động cơ lớn hơn kw',
#  'công suất động cơ điện dưới kw',
#  'công suất động cơ điện kw',
#  'công suất động cơ điện kw dưới kw',
#  'công suất động cơ điện kw trở',
#  'công suất động cơ điện trên kw',
#  'công thức cbthtkt năm gxdhtkt',
#  'công thức sau',
#  'công thức sau cbtctdd năm gxdctdd',
#  'công thức sau cbtnăm cbtctdd năm cbthtkt năm',
#  'công trình biển',
#  'công trình bảo đảm an toàn',
#  'công trình bến phà đường bộ',
#  'công trình bị hư hỏng',
#  'công trình bộ phận công trình đường bộ',
#  'công trình cscct',
#  'công trình công cộng tập trung đông người',
#  'công trình công nghiệp vật liệu xây dựng được',
#  'công trình cấp cấp đặc biệt hệ thống đường trung ương',
#  'công trình cấp i',
#  'công trình cấp điện',
#  'công trình cấp đặc biệt',
#  'công trình cầu hầm đường bộ hồ sơ lý lịch cầu',
#  'công trình dân dụng sau thuế',
#  'công trình dân dụng theo',
#  'công trình dân dụng thuế',
#  'công trình dân dụng được',
#  'công trình dự án',
#  'công trình dự án theo',
#  'công trình dự án theo quy định hợp đồng dự án',
#  'công trình dự án theo quy định thông tư này',
#  'công trình hoàn thành',
#  'công trình hạ tầng kỹ thuật theo',
#  'công trình hạ tầng kỹ thuật đô thị',
#  'công trình hạng mục công trình công việc',
#  'công trình hầm có',
#  'công trình khi hư hỏng được',
#  'công trình khi số liệu quan trắc có dấu hiệu bất thường',
#  'công trình khi số liệu quan trắc vượt giá trị giới hạn cho phép',
#  'công trình khác',
#  'công trình khác theo',
#  'công trình mình',
#  'công trình mình quản lý',
#  'công trình mình quản lý khi',
#  'công trình mất an toàn giao thông',
#  'công trình nhà thầu quản lý',
#  'công trình phụ trợ khác đường bộ',
#  'công trình quy định pháp luật',
#  'công trình quy định thời hạn dự kiến',
#  'công trình quá trình khai thác',
#  'công trình sửa chữa kế hoạch bảo trì phê duyệt',
#  'công trình theo',
#  'công trình thiết bị lắp đặt công trình',
#  'công trình thiết kế',
#  'công trình thiết yếu phạm vi hành lang an toàn đường bộ',
#  'công trình trường hợp hư hỏng',
#  'công trình trường hợp quy định điểm khoản điều này',
#  'công trình trường hợp thuộc',
#  'công trình trạm',
#  'công trình tương tự',
#  'công trình xây dựng khẩn cấp',
#  'công trình xây dựng theo',
#  'công trình xây dựng đây',
#  'công trình xây dựng đưa sử dụng',
#  'công trình đúng công năng',
#  'công trình đúng công suất công năng',
#  'công trình đưa',
#  'công trình đưa khai thác quy định khoản điều thẩm quyền phê duyệt',
#  'công trình đường bộ',
#  'công trình đường bộ chủ sở hữu',
#  'công trình đường bộ công trình quy định phụ lục ban hành',
#  'công trình đường bộ công trình đường bộ',
#  'công trình đường bộ công trình đường bộ khai thác',
#  'công trình đường bộ cơ sở hạ tầng phục vụ gồm nhà làm việc',
#  'công trình đường bộ hiệu quả',
#  'công trình đường bộ hàng năm',
#  'công trình đường bộ hàng năm được phê duyệt',
#  'công trình đường bộ hình thức đối tác công tư',
#  'công trình đường bộ hư hỏng xuống cấp',
#  'công trình đường bộ hệ thống',
#  'công trình đường bộ hệ thống thu thập',
#  'công trình đường bộ hệ thống xử lý gồm hệ thống lưu trữ',
#  'công trình đường bộ hệ thống đường trung ương',
#  'công trình đường bộ hệ thống đường trung ương thẩm quyền',
#  'công trình đường bộ khai thác',
#  'công trình đường bộ khai thác có yêu cầu đặc thù',
#  'công trình đường bộ khi',
#  'công trình đường bộ khi bàn giao cơ quan',
#  'công trình đường bộ mình quản lý',
#  'công trình đường bộ nguồn vốn khác',
#  'công trình đường bộ năm ngày tháng',
#  'công trình đường bộ phạm vi quản lý',
#  'công trình đường bộ phạm vi được',
#  'công trình đường bộ phục vụ việc',
#  'công trình đường bộ quy định điểm khoản',
#  'công trình đường bộ quá trình khai thác',
#  'công trình đường bộ theo',
#  'công trình đường bộ theo pháp luật',
#  'công trình đường bộ theo quy chuẩn tiêu chuẩn kỹ thuật quy trình bảo trì',
#  'công trình đường bộ theo đúng quy định pháp luật',
#  'công trình đường bộ thi công',
#  'công trình đường bộ thường xuyên định kỳ',
#  'công trình đường bộ thời hạn bảo hành',
#  'công trình đường bộ tiêu chuẩn thiết kế tiêu chuẩn kỹ thuật quy trình bảo trì',
#  'công trình đường bộ trường hợp quy định khoản điều',
#  'công trình đường bộ trường hợp đặc thù',
#  'công trình đường bộ tuyến đường được',
#  'công trình đường bộ tổng cục đường bộ việt nam',
#  'công trình đường bộ từng quý ngày tháng',
#  'công trình đường bộ tự',
#  'công trình đường bộ vượt',
#  'công trình đường bộ được',
#  'công trình đường bộ được đầu tư xây dựng mới cải tạo nâng cấp',
#  'công trình đường bộ đầu tư',
#  'công trình đường bộ đầu tư xây dựng',
#  'công trình đường bộ định kỳ từng quý ngày tháng',
#  'công trình đường mình quản lý',
#  'công trình đường ô tô cấp i trở',
#  'công trình được',
#  'công trình được duyệt',
#  'công trình đầu tư theo hình thức ppp',
#  'công trình đặc thù khác',
#  'công trình đột xuất yêu cầu',
#  'công tác bảo dưỡng thường xuyên công trình đường bộ',
#  'công tác bảo trì',
#  'công tác bảo trì tuyến đường',
#  'công tác bảo vệ',
#  'công tác bảo vệ phân làn xe',
#  'công tác giám sát',
#  'công tác giám sát hậu kiểm',
#  'công tác giám sát hậu kiểm trạm',
#  'công tác giám sát kiểm vé lượt cuối ca lượt xe',
#  'công tác hậu kiểm',
#  'công tác kế toán',
#  'công tác nghiệm thu cơ quan',
#  'công tác quản lý',
#  'công tác quản lý bảo dưỡng thường xuyên sử dụng nguồn vốn ngân sách địa phương',
#  'công tác quản lý bảo dưỡng thường xuyên sử dụng ngân sách trung ương',
#  'công tác quản lý nhà nước',
#  'công tác quản lý tuyến đường',
#  'công tác thanh tra',
#  'công tác thu',
#  'công tác trực tiếp bán soát vé',
#  'công tác trực tiếp bán soát vé cabin',
#  'công tác tuần tra',
#  'công tác vận hành',
#  'công tác điều hành',
#  'công tác đấu thầu đặt hàng',
#  'công việc bảo dưỡng',
#  'công việc bảo trì',
#  'công việc bảo trì kế hoạch bảo trì hàng năm',
#  'công việc cơ quan nhà nước',
#  'công việc cần thiết bổ sung',
#  'công việc cần thiết khác',
#  'công việc cần thiết khác cấp',
#  'công việc cần thiết khác liên quan',
#  'công việc khác',
#  'công việc khác ngày tháng hàng năm',
#  'công việc khác theo',
#  'công việc khảo sát',
#  'công việc kiểm tra',
#  'công việc kế hoạch',
#  'công việc kế hoạch bảo trì',
#  'công việc kế hoạch bảo trì duyệt',
#  'công việc quy định khoản điều nghị định số',
#  'công việc quy định điểm nêu trên',
#  'công việc quản lý',
#  'công việc sau',
#  'công việc sửa chữa đột xuất có giá trị nhỏ hơn đồng',
#  'công việc sửa chữa đột xuất có giá trị đồng đồng',
#  'công việc theo',
#  'công việc tư vấn',
#  'công việc tư vấn khác theo',
#  'công việc tổ chức',
#  'công việc đó',
#  'công việc được',
#  'công việc được ưu tiên',
#  'công việc ưu tiên cho phép',
#  'công việc ưu tiên kế hoạch bảo trì hàng năm',
#  'công vụ',
#  'công vụ được',
#  'công ước liên hợp quốc giao thông đường bộ năm được',
#  'công ước quốc tế tương ứng',
#  'công ước viên',
#  'công-te-nơ máy vật liệu trang thiết bị',
#  'cùng hạng',
#  'căn cứ chỉ dẫn kỹ thuật này thiết kế cơ sở dự án loại thiết bị công nghệ vận hành khai thác công trình chế độ hao mòn',
#  'căn cứ lập quy trình',
#  'cơ quan chức năng',
#  'cơ quan công an',
#  'cơ quan công an khi phát hiện',
#  'cơ quan công an nơi',
#  'cơ quan công an uỷ ban nhân dân nơi gần',
#  'cơ quan cảnh sát giao thông',
#  'cơ quan kiểm tra',
#  'cơ quan nhận',
#  'cơ quan nhận báo cáo hệ thống thư điện tử',
#  'cơ quan nhận báo cáo phương thức sau gửi trực tiếp dịch vụ bưu chính fax hệ thống thư điện tử',
#  'cơ quan quy định khoản điều này',
#  'cơ quan quy định điểm a',
#  'cơ quan quyết định công việc sửa chữa đột xuất điểm này',
#  'cơ quan quản lý nhà nước có thẩm quyền',
#  'cơ quan thẩm quyền',
#  'cơ quan thẩm định',
#  'cơ quan tổ chức cá nhân có',
#  'cơ quan tổ chức cá nhân có liên quan',
#  'cơ sở bộ phận kết cấu công trình xem xét',
#  'cơ sở dữ liệu',
#  'cơ sở dữ liệu bảo hiểm chủ xe cơ giới',
#  'cơ sở dữ liệu chi phí quản lý',
#  'cơ sở dữ liệu chứng chỉ',
#  'cơ sở dữ liệu cầu',
#  'cơ sở dữ liệu cầu hồ sơ',
#  'cơ sở dữ liệu hành trình phương tiện giao thông đường bộ',
#  'cơ sở dữ liệu khác liên quan công tác',
#  'cơ sở dữ liệu người',
#  'cơ sở dữ liệu quản lý thời gian',
#  'cơ sở dữ liệu tai nạn giao thông đường bộ',
#  'cơ sở dữ liệu trật tự an toàn giao thông đường bộ',
#  'cơ sở dữ liệu xe máy chuyên dùng',
#  'cơ sở dữ liệu đào tạo',
#  'cơ sở dữ liệu đường bộ',
#  'cơ sở dữ liệu đường bộ hồ sơ',
#  'cơ sở dữ liệu đường bộ kết cấu hạ tầng giao thông đường bộ',
#  'cơ sở lập quy trình bảo trì',
#  'cơ sở nhập khẩu',
#  'cơ sở nhập khẩu bổ sung',
#  'cơ sở nhập khẩu thời gian',
#  'cơ sở nhập khẩu thời hạn ngày làm việc',
#  'cơ sở quy mô công suất',
#  'cơ sở sản xuất',
#  'cơ sở sản xuất trường hợp',
#  'cơ sở sản xuất tự',
#  'cơ sở thiết kế',
#  'cơ sở thiết kế nộp hồ sơ hình thức phù hợp khác cơ quan đăng kiểm',
#  'cơ sở thiết kế nộp hồ sơ hệ thống bưu chính cơ quan đăng kiểm',
#  'cơ sở thiết kế nộp hồ sơ hệ thống dịch vụ công trực tuyến cơ quan đăng kiểm',
#  'cơ sở thiết kế nộp hồ sơ trực tiếp cơ quan đăng kiểm',
#  'cơ sở thử nghiệm',
#  'cơ sở trường hợp',
#  'cơ sở việc cải tạo',
#  'cả',
#  'cả chi phí bảo dưỡng công trình',
#  'cả chi phí bảo dưỡng hệ thống',
#  'cả chi phí thiết bị lắp đặt công trình dân dụng',
#  'cả khoản người',
#  'cả năm',
#  'cả tay khi lái xe',
#  'cả thời gian thực hiện',
#  'cả tiền điện tính giá ca máy',
#  'cả trạm giao dịch thanh toán phương tiện',
#  'cả xe đạp điện',
#  'cảng nhà máy',
#  'cảnh sát giao thông thực hiện',
#  'cấp bậc bình quân nhân công tham gia',
#  'cấp bậc nhân công',
#  'cấp bậc tương ứng',
#  'cấp hạng mục công trình',
#  'cấp điện',
#  'cấu trúc biểu mẫu chứng nhận đăng ký xe biển số xe',
#  'cấu tạo mốc quan trắc',
#  'cần cẩu',
#  'cần cẩu phục vụ việc',
#  'cầu cống',
#  'cầu hẹp',
#  'cầu phao',
#  'cầu phao người',
#  'cầu phao theo thứ tự ưu tiên trên dưới',
#  'cầu phao đường bộ',
#  'cầu vượt dành người',
#  'cầu yếu',
#  'cầu đường bộ',
#  'cầu đường bộ cầu phao đường bộ',
#  'cọc h',
#  'cọc tiêu',
#  'cố định đường bộ',
#  'cột km',
#  'cục đăng kiểm việt nam',
#  'cụm trục xe',
#  'danh mục bản vẽ kèm theo',
#  'danh mục công trình đường bộ bắt buộc phải quan trắc quá trình khai thác sử dụng được',
#  'danh mục hồ sơ',
#  'danh mục khối lượng công việc',
#  'danh mục kèm',
#  'danh mục phụ tùng',
#  'danh mục quy định điểm khoản này',
#  'danh mục sản phẩm hàng hoá phải',
#  'danh mục thiết bị',
#  'danh mục thiết bị phụ tùng vật tư dự trữ thay thế',
#  'danh mục tuyến đường cần thiết',
#  'danh mục tuyến đường ưu tiên',
#  'danh mục tuyến đường ưu tiên cho phép',
#  'danh mục tuyến đường ưu tiên quy định điểm khoản điều này',
#  'danh mục vật tư dự trữ',
#  ...]

# %%
import random

def get_random_triplets(session, limit=10):
    """
    Extract random triplets (concept1 -[relation]-> concept2) from Neo4j.
    Returns a list of (concept1, relation, concept2).
    """
    with session.begin_transaction() as tx:
        result = tx.run("""
            MATCH (c1:Concept)-[r:RELATION]->(c2:Concept)
            WHERE r.name IS NOT NULL
            RETURN c1.name AS concept1, r.name AS relation, c2.name AS concept2
        """)
        triplets = [(rec["concept1"], rec["relation"], rec["concept2"]) for rec in result]

    if not triplets:
        print("No triplets found in Neo4j.")
        return []

    # Pick random subset
    sample = random.sample(triplets, min(limit, len(triplets)))

    print(f"\n🎲 Showing {len(sample)} random triplets out of {len(triplets)} total:\n")
    for i, (c1, rel, c2) in enumerate(sample, start=1):
        print(f"{i:02d}. {c1} —[{rel}]→ {c2}")

    return sample

# %%
get_random_triplets(neo4j_session, limit=5)
# Out:
# 🎲 Showing 5 random triplets out of 6918 total:
#
# 01. trường hợp xe quá khổ giới hạn —[NEW01]→ quá khổ giới hạn công trình đường bộ
# 02. báo cáo kết quả —[xử lý]→ vi phạm địa phương
# 03. sở giao thông vận tải —[NEW01]→ G71
# 04. J220 —[N167]→ định kỳ hàng năm hạng mục công trình dân dụng
# 05. hợp đồng dự án thực hiện —[N167]→ công trình đường bộ đầu tư
# [('trường hợp xe quá khổ giới hạn',
#   'NEW01',
#   'quá khổ giới hạn công trình đường bộ'),
#  ('báo cáo kết quả', 'xử lý', 'vi phạm địa phương'),
#  ('sở giao thông vận tải', 'NEW01', 'G71'),
#  ('J220', 'N167', 'định kỳ hàng năm hạng mục công trình dân dụng'),
#  ('hợp đồng dự án thực hiện', 'N167', 'công trình đường bộ đầu tư')]

# %%
def extract_triplets_for_relations(session, relation_names, output_path="triplets_by_relation.txt"):
    """
    Extract all triplets for a list of relation names and export them to a text file.

    Args:
        session: Active Neo4j session.
        relation_names (list[str]): List of relation names to extract.
        output_path (str): File path to save the results.

    Returns:
        dict: {relation_name: [(subject, relation, object), ...]}
    """
    all_triplets = {}

    with open(output_path, "w", encoding="utf-8") as f:
        for rel_name in relation_names:
            with session.begin_transaction() as tx:
                result = tx.run("""
                    MATCH (s)-[r:RELATION {name: $relation_name}]->(o)
                    RETURN s.name AS subject, r.name AS relation, o.name AS object
                    ORDER BY s.name, o.name
                """, relation_name=rel_name)
                triplets = [
                    (record["subject"], record["relation"], record["object"])
                    for record in result
                ]

            all_triplets[rel_name] = triplets

            # Write section header and triplets to file
            f.write(f"=== Relation: {rel_name} ===\n")
            for s, r, o in triplets:
                f.write(f"{s}\t{r}\t{o}\n")
            f.write("\n")

            print(f"✅ Found {len(triplets)} triplets for relation '{rel_name}'")

    print(f"\n📄 All triplets saved to: {output_path}")
    return all_triplets

# %%
relations_to_find = [
    "cấp đăng ký"
]
results = extract_triplets_for_relations(neo4j_session, relations_to_find)
for result in results:
    print(result)
# Out:
# ✅ Found 1 triplets for relation 'cấp đăng ký'
#
# 📄 All triplets saved to: triplets_by_relation.txt
# cấp đăng ký
